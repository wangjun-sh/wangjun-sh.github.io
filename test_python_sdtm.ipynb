# %%
import pandas as pd


# https://github.com/phuse-org/phuse-scripts/blob/master/data/sdtm/cdiscpilot_update2/
    
mydm = pd.read_sas("SDTM/dm.xpt", format="xport", encoding="utf-8")
myae = pd.read_sas("SDTM/ae.xpt", format="xport", encoding="utf-8")
mycm = pd.read_sas("SDTM/cm.xpt", format="xport", encoding="utf-8")

## SAS XPORT
#libname xportin xport 'C:\Users\john-dell\Desktop\dm.xpt';
#libname target 'C:\Users\john-dell\Desktop';
#proc copy in=xportin out=target;
#  select dm;
#run;

# %%
import warnings
warnings.simplefilter('ignore')

# %%
mydm.head()
# Out:
#         STUDYID DOMAIN      USUBJID SUBJID     RFSTDTC     RFENDTC  \
# 0  CDISCPILOT01     DM  01-701-1015   1015  2014-01-02  2014-07-02
# 1  CDISCPILOT01     DM  01-701-1023   1023  2012-08-05  2012-09-02
# 2  CDISCPILOT01     DM  01-701-1028   1028  2013-07-19  2014-01-14
# 3  CDISCPILOT01     DM  01-701-1033   1033  2014-03-18  2014-04-14
# 4  CDISCPILOT01     DM  01-701-1034   1034  2014-07-01  2014-12-30
#
#      RFXSTDTC    RFXENDTC RFICDTC          RFPENDTC  ...  SEX   RACE  \
# 0  2014-01-02  2014-07-02          2014-07-02T11:45  ...    F  WHITE
# 1  2012-08-05  2012-09-01                2013-02-18  ...    M  WHITE
# 2  2013-07-19  2014-01-14          2014-01-14T11:10  ...    M  WHITE
# 3  2014-03-18  2014-03-31                2014-09-15  ...    M  WHITE
# 4  2014-07-01  2014-12-30          2014-12-30T09:50  ...    F  WHITE
#
#                    ETHNIC   ARMCD                   ARM ACTARMCD  \
# 0      HISPANIC OR LATINO     Pbo               Placebo      Pbo
# 1      HISPANIC OR LATINO     Pbo               Placebo      Pbo
# 2  NOT HISPANIC OR LATINO  Xan_Hi  Xanomeline High Dose   Xan_Hi
# 3  NOT HISPANIC OR LATINO  Xan_Lo   Xanomeline Low Dose   Xan_Lo
# 4  NOT HISPANIC OR LATINO  Xan_Hi  Xanomeline High Dose   Xan_Hi
#
#                  ACTARM COUNTRY       DMDTC  DMDY
# 0               Placebo     USA  2013-12-26  -7.0
# 1               Placebo     USA  2012-07-22 -14.0
# 2  Xanomeline High Dose     USA  2013-07-11  -8.0
# 3   Xanomeline Low Dose     USA  2014-03-10  -8.0
# 4  Xanomeline High Dose     USA  2014-06-24  -7.0
#
# [5 rows x 25 columns]

# %%
myae.head()
# Out:
#         STUDYID DOMAIN      USUBJID  AESEQ AESPID  \
# 0  CDISCPILOT01     AE  01-701-1015    1.0    E07
# 1  CDISCPILOT01     AE  01-701-1015    2.0    E08
# 2  CDISCPILOT01     AE  01-701-1015    3.0    E06
# 3  CDISCPILOT01     AE  01-701-1023    3.0    E10
# 4  CDISCPILOT01     AE  01-701-1023    2.0    E09
#
#                                  AETERM                     AELLT  AELLTCD  \
# 0             APPLICATION SITE ERYTHEMA  APPLICATION SITE REDNESS      NaN
# 1             APPLICATION SITE PRURITUS  APPLICATION SITE ITCHING      NaN
# 2                             DIARRHOEA                  DIARRHEA      NaN
# 3  ATRIOVENTRICULAR BLOCK SECOND DEGREE    AV BLOCK SECOND DEGREE      NaN
# 4                              ERYTHEMA        LOCALIZED ERYTHEMA      NaN
#
#                                 AEDECOD  AEPTCD  ...   AESHOSP  AESLIFE AESOD  \
# 0             APPLICATION SITE ERYTHEMA     NaN  ...         N        N     N
# 1             APPLICATION SITE PRURITUS     NaN  ...         N        N     N
# 2                             DIARRHOEA     NaN  ...         N        N     N
# 3  ATRIOVENTRICULAR BLOCK SECOND DEGREE     NaN  ...         N        N     N
# 4                              ERYTHEMA     NaN  ...         N        N     N
#
#        EPOCH       AEDTC     AESTDTC     AEENDTC  AEDY AESTDY AEENDY
# 0  TREATMENT  2014-01-16  2014-01-03              15.0    2.0    NaN
# 1  TREATMENT  2014-01-16  2014-01-03              15.0    2.0    NaN
# 2  TREATMENT  2014-01-16  2014-01-09  2014-01-11  15.0    8.0   10.0
# 3  TREATMENT  2012-08-27  2012-08-26              23.0   22.0    NaN
# 4  TREATMENT  2012-08-27  2012-08-07              23.0    3.0    NaN
#
# [5 rows x 37 columns]

# %%
myae.columns
# Out:
# Index(['STUDYID', 'DOMAIN', 'USUBJID', 'AESEQ', 'AESPID', 'AETERM', 'AELLT',
#        'AELLTCD', 'AEDECOD', 'AEPTCD', 'AEHLT', 'AEHLTCD', 'AEHLGT',
#        'AEHLGTCD', 'AEBODSYS', 'AEBDSYCD', 'AESOC', 'AESOCCD', 'AESEV',
#        'AESER', 'AEACN', 'AEREL', 'AEOUT', 'AESCAN', 'AESCONG', 'AESDISAB',
#        'AESDTH', 'AESHOSP', 'AESLIFE', 'AESOD', 'EPOCH', 'AEDTC', 'AESTDTC',
#        'AEENDTC', 'AEDY', 'AESTDY', 'AEENDY'],
#       dtype='object')

# %%
mycm.head()
# Out:
#         STUDYID DOMAIN      USUBJID  CMSEQ CMSPID     CMTRT  \
# 0  CDISCPILOT01     CM  01-701-1015    1.0      1   ASPIRIN
# 1  CDISCPILOT01     CM  01-701-1015    2.0      4   TYLENOL
# 2  CDISCPILOT01     CM  01-701-1015    3.0      3  PREMARIN
# 3  CDISCPILOT01     CM  01-701-1015    4.0      2   CALCIUM
# 4  CDISCPILOT01     CM  01-701-1015    5.0      1   ASPIRIN
#
#                 CMDECOD                              CMINDC  \
# 0  ACETYLSALICYLIC ACID
# 1               UNCODED
# 2  ESTROGENS CONJUGATED  PROPHYLAXIS OR NON-THERAPEUTIC USE
# 3               CALCIUM  PROPHYLAXIS OR NON-THERAPEUTIC USE
# 4  ACETYLSALICYLIC ACID
#
#                                    CMCLAS  CMDOSE  ...   VISITNUM  \
# 0                          NERVOUS SYSTEM   1.000  ...        1.0
# 1                                 UNCODED   1.000  ...        1.0
# 2  GENITO URINARY SYSTEM AND SEX HORMONES   0.625  ...        1.0
# 3         ALIMENTARY TRACT AND METABOLISM   1.000  ...        1.0
# 4                          NERVOUS SYSTEM   1.000  ...        2.0
#
#          VISIT VISITDY      EPOCH       CMDTC  CMSTDTC CMENDTC CMDY CMSTDY  \
# 0  SCREENING 1    -7.0  SCREENING  2013-12-26     2003         -7.0    NaN
# 1  SCREENING 1    -7.0  SCREENING  2013-12-26     2003         -7.0    NaN
# 2  SCREENING 1    -7.0  SCREENING  2013-12-26     2006         -7.0    NaN
# 3  SCREENING 1    -7.0  SCREENING  2013-12-26     2013         -7.0    NaN
# 4  SCREENING 2    -1.0  SCREENING  2013-12-31     2003         -2.0    NaN
#
#   CMENDY
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 23 columns]

# %%
mycm["CMDECOD"]
# Out:
# 0       ACETYLSALICYLIC ACID
# 1                    UNCODED
# 2       ESTROGENS CONJUGATED
# 3                    CALCIUM
# 4       ACETYLSALICYLIC ACID
# 5                    UNCODED
# 6       ESTROGENS CONJUGATED
# 7                    CALCIUM
# 8       ACETYLSALICYLIC ACID
# 9                    UNCODED
# 10      ESTROGENS CONJUGATED
# 11                   CALCIUM
# 12      ACETYLSALICYLIC ACID
# 13                   UNCODED
# 14      ESTROGENS CONJUGATED
# 15                   CALCIUM
# 16                   UNCODED
# 17      ACETYLSALICYLIC ACID
# 18                   UNCODED
# 19      ESTROGENS CONJUGATED
# 20                   CALCIUM
# 21                   UNCODED
# 22      ACETYLSALICYLIC ACID
# 23                   UNCODED
# 24      ESTROGENS CONJUGATED
# 25                   CALCIUM
# 26                   UNCODED
# 27      ACETYLSALICYLIC ACID
# 28                   UNCODED
# 29      ESTROGENS CONJUGATED
#                 ...
# 7480                 UNCODED
# 7481                 UNCODED
# 7482                 UNCODED
# 7483                 UNCODED
# 7484                 UNCODED
# 7485                 UNCODED
# 7486                 UNCODED
# 7487                 UNCODED
# 7488                 UNCODED
# 7489                 UNCODED
# 7490                 UNCODED
# 7491                 UNCODED
# 7492                 UNCODED
# 7493                 UNCODED
# 7494                 UNCODED
# 7495                 UNCODED
# 7496                 UNCODED
# 7497                 UNCODED
# 7498                 UNCODED
# 7499                 UNCODED
# 7500                 UNCODED
# 7501                 UNCODED
# 7502                 UNCODED
# 7503                 UNCODED
# 7504                 UNCODED
# 7505                 UNCODED
# 7506                 UNCODED
# 7507                 UNCODED
# 7508                 UNCODED
# 7509                 UNCODED
# Name: CMDECOD, Length: 7510, dtype: object

# %%
mycm.columns
# Out:
# Index(['STUDYID', 'DOMAIN', 'USUBJID', 'CMSEQ', 'CMSPID', 'CMTRT', 'CMDECOD',
#        'CMINDC', 'CMCLAS', 'CMDOSE', 'CMDOSU', 'CMDOSFRQ', 'CMROUTE',
#        'VISITNUM', 'VISIT', 'VISITDY', 'EPOCH', 'CMDTC', 'CMSTDTC', 'CMENDTC',
#        'CMDY', 'CMSTDY', 'CMENDY'],
#       dtype='object')

# %%
mydm = mydm.drop(columns=['STUDYID','DOMAIN'])
myae = myae.drop(columns=['STUDYID','DOMAIN'])

mydmae = pd.merge(mydm, myae,on=["USUBJID"])
mydmae.head()
# Out:
#        USUBJID SUBJID     RFSTDTC     RFENDTC    RFXSTDTC    RFXENDTC RFICDTC  \
# 0  01-701-1015   1015  2014-01-02  2014-07-02  2014-01-02  2014-07-02
# 1  01-701-1015   1015  2014-01-02  2014-07-02  2014-01-02  2014-07-02
# 2  01-701-1015   1015  2014-01-02  2014-07-02  2014-01-02  2014-07-02
# 3  01-701-1023   1023  2012-08-05  2012-09-02  2012-08-05  2012-09-01
# 4  01-701-1023   1023  2012-08-05  2012-09-02  2012-08-05  2012-09-01
#
#            RFPENDTC DTHDTC DTHFL  ...   AESHOSP  AESLIFE AESOD      EPOCH  \
# 0  2014-07-02T11:45               ...         N        N     N  TREATMENT
# 1  2014-07-02T11:45               ...         N        N     N  TREATMENT
# 2  2014-07-02T11:45               ...         N        N     N  TREATMENT
# 3        2013-02-18               ...         N        N     N  TREATMENT
# 4        2013-02-18               ...         N        N     N  TREATMENT
#
#         AEDTC     AESTDTC     AEENDTC  AEDY AESTDY AEENDY
# 0  2014-01-16  2014-01-03              15.0    2.0    NaN
# 1  2014-01-16  2014-01-03              15.0    2.0    NaN
# 2  2014-01-16  2014-01-09  2014-01-11  15.0    8.0   10.0
# 3  2012-08-27  2012-08-26              23.0   22.0    NaN
# 4  2012-08-27  2012-08-07              23.0    3.0    NaN
#
# [5 rows x 57 columns]

# %%
# import ggplot
#from ggplot import *

## alternative, plotnine
## http://pltn.ca/plotnine-superior-python-ggplot/
from plotnine import *
#https://www.kaggle.com/residentmario/grammar-of-graphics-with-plotnine-optional

# %%
midwest= pd.read_csv("http://goo.gl/G1K41K") 
midwest= midwest[midwest.poptotal<50000]
(ggplot(aes(x='area', y='poptotal', color='state', size='popdensity'), data=midwest) +\
    geom_point() +\
    theme_bw() +\
    xlab("Area") +\
    ylab("Population") +\
    ggtitle("Area vs Population")
)
# Out:
# <ggplot: (-9223363251155045972)>

# %%
mydmae1 = mydmae.query('USUBJID == "01-701-1015"')

(ggplot(aes(x="AEDECOD", y="AESTDY",  color="AESEV"), data=mydmae1) + \
    geom_bar(stat="identity") +\
    coord_flip() +\
    theme_bw() +\
    ylab("study day") +\
    xlab("adverse event") +\
    ggtitle("adverse event by study day")
)
# Out:
# <ggplot: (8785699729847)>

# %%
mydmae1 = mydmae.query('USUBJID == u"01-701-1015"')

# %%
mydmae1.head()
# Out:
#        USUBJID SUBJID     RFSTDTC     RFENDTC    RFXSTDTC    RFXENDTC RFICDTC  \
# 0  01-701-1015   1015  2014-01-02  2014-07-02  2014-01-02  2014-07-02
# 1  01-701-1015   1015  2014-01-02  2014-07-02  2014-01-02  2014-07-02
# 2  01-701-1015   1015  2014-01-02  2014-07-02  2014-01-02  2014-07-02
#
#            RFPENDTC DTHDTC DTHFL  ...   AESHOSP  AESLIFE AESOD      EPOCH  \
# 0  2014-07-02T11:45               ...         N        N     N  TREATMENT
# 1  2014-07-02T11:45               ...         N        N     N  TREATMENT
# 2  2014-07-02T11:45               ...         N        N     N  TREATMENT
#
#         AEDTC     AESTDTC     AEENDTC  AEDY AESTDY AEENDY
# 0  2014-01-16  2014-01-03              15.0    2.0    NaN
# 1  2014-01-16  2014-01-03              15.0    2.0    NaN
# 2  2014-01-16  2014-01-09  2014-01-11  15.0    8.0   10.0
#
# [3 rows x 57 columns]
