# %% [markdown]
# # 使用advs来生成Summary Table

# %%
import pandas as pd
import numpy as np
from plotnine import *
# %matplotlib inline


advs = pd.read_sas("./data/processed/advs.xpt")

# %%
from pathlib import Path
from datetime import datetime

# %%
advs1 = advs.loc[(advs["ANL01FL"] == b"Y") & (advs["PARAM"] == b'Diastolic Blood Pressure (mmHg)')]
gg = advs1.groupby(["TRTPN","TRTP","AVISITN","AVISIT"])

# %%
advs1.head()
# Out:
#            STUDYID  SITEID         USUBJID   AGE  AGEGR1  AGEGR1N      RACE  \
# 2  b'CDISCPILOT01'  b'701'  b'01-701-1015'  63.0  b'<65'      1.0  b'WHITE'
# 4  b'CDISCPILOT01'  b'701'  b'01-701-1015'  63.0  b'<65'      1.0  b'WHITE'
# 5  b'CDISCPILOT01'  b'701'  b'01-701-1015'  63.0  b'<65'      1.0  b'WHITE'
# 7  b'CDISCPILOT01'  b'701'  b'01-701-1015'  63.0  b'<65'      1.0  b'WHITE'
# 8  b'CDISCPILOT01'  b'701'  b'01-701-1015'  63.0  b'<65'      1.0  b'WHITE'
#
#    RACEN   SEX SAFFL  ...    AVAL  BASE                           BASETYPE  \
# 2    1.0  b'F'  b'Y'  ...    56.0  56.0  b'AFTER LYING DOWN FOR 5 MINUTES'
# 4    1.0  b'F'  b'Y'  ...    56.0  56.0  b'AFTER LYING DOWN FOR 5 MINUTES'
# 5    1.0  b'F'  b'Y'  ...    64.0  56.0  b'AFTER LYING DOWN FOR 5 MINUTES'
# 7    1.0  b'F'  b'Y'  ...    55.0  56.0  b'AFTER LYING DOWN FOR 5 MINUTES'
# 8    1.0  b'F'  b'Y'  ...    67.0  56.0  b'AFTER LYING DOWN FOR 5 MINUTES'
#
#             CHG          PCHG  VISITNUM        VISIT VSSEQ  ANL01FL  ABLFL
# 2  5.397605e-79  5.397605e-79       3.0  b'BASELINE'   7.0     b'Y'   b'Y'
# 4  5.397605e-79  5.397605e-79       4.0    b'WEEK 2'  13.0     b'Y'    b''
# 5  8.000000e+00  1.428571e+01       5.0    b'WEEK 4'  16.0     b'Y'    b''
# 7 -1.000000e+00 -1.785714e+00       7.0    b'WEEK 6'  22.0     b'Y'    b''
# 8  1.100000e+01  1.964286e+01       8.0    b'WEEK 8'  25.0     b'Y'    b''
#
# [5 rows x 35 columns]

# %%
gg["PARAM"].value_counts()
# Out:
# TRTPN         TRTP                     AVISITN       AVISIT               PARAM
# 5.397605e-79  b'Placebo'               5.397605e-79  b'Baseline'          b'Diastolic Blood Pressure (mmHg)'    255
#                                        2.000000e+00  b'Week 2'            b'Diastolic Blood Pressure (mmHg)'    252
#                                        4.000000e+00  b'Week 4'            b'Diastolic Blood Pressure (mmHg)'    246
#                                        6.000000e+00  b'Week 6'            b'Diastolic Blood Pressure (mmHg)'    228
#                                        8.000000e+00  b'Week 8'            b'Diastolic Blood Pressure (mmHg)'    219
#                                        1.200000e+01  b'Week 12'           b'Diastolic Blood Pressure (mmHg)'    207
#                                        1.600000e+01  b'Week 16'           b'Diastolic Blood Pressure (mmHg)'    204
#                                        2.000000e+01  b'Week 20'           b'Diastolic Blood Pressure (mmHg)'    198
#                                        2.400000e+01  b'Week 24'           b'Diastolic Blood Pressure (mmHg)'    177
#                                        2.600000e+01  b'Week 26'           b'Diastolic Blood Pressure (mmHg)'    174
#                                        9.900000e+01  b'End of Treatment'  b'Diastolic Blood Pressure (mmHg)'    246
# 5.400000e+01  b'Xanomeline Low Dose'   5.397605e-79  b'Baseline'          b'Diastolic Blood Pressure (mmHg)'    252
#                                        2.000000e+00  b'Week 2'            b'Diastolic Blood Pressure (mmHg)'    252
#                                        4.000000e+00  b'Week 4'            b'Diastolic Blood Pressure (mmHg)'    216
#                                        6.000000e+00  b'Week 6'            b'Diastolic Blood Pressure (mmHg)'    195
#                                        8.000000e+00  b'Week 8'            b'Diastolic Blood Pressure (mmHg)'    180
#                                        1.200000e+01  b'Week 12'           b'Diastolic Blood Pressure (mmHg)'    156
#                                        1.600000e+01  b'Week 16'           b'Diastolic Blood Pressure (mmHg)'    126
#                                        2.000000e+01  b'Week 20'           b'Diastolic Blood Pressure (mmHg)'     90
#                                        2.400000e+01  b'Week 24'           b'Diastolic Blood Pressure (mmHg)'     81
#                                        2.600000e+01  b'Week 26'           b'Diastolic Blood Pressure (mmHg)'     75
#                                        9.900000e+01  b'End of Treatment'  b'Diastolic Blood Pressure (mmHg)'    216
# 8.100000e+01  b'Xanomeline High Dose'  5.397605e-79  b'Baseline'          b'Diastolic Blood Pressure (mmHg)'    252
#                                        2.000000e+00  b'Week 2'            b'Diastolic Blood Pressure (mmHg)'    243
#                                        4.000000e+00  b'Week 4'            b'Diastolic Blood Pressure (mmHg)'    219
#                                        6.000000e+00  b'Week 6'            b'Diastolic Blood Pressure (mmHg)'    203
#                                        8.000000e+00  b'Week 8'            b'Diastolic Blood Pressure (mmHg)'    168
#                                        1.200000e+01  b'Week 12'           b'Diastolic Blood Pressure (mmHg)'    150
#                                        1.600000e+01  b'Week 16'           b'Diastolic Blood Pressure (mmHg)'    111
#                                        2.000000e+01  b'Week 20'           b'Diastolic Blood Pressure (mmHg)'     96
#                                        2.400000e+01  b'Week 24'           b'Diastolic Blood Pressure (mmHg)'     90
#                                        2.600000e+01  b'Week 26'           b'Diastolic Blood Pressure (mmHg)'     84
#                                        9.900000e+01  b'End of Treatment'  b'Diastolic Blood Pressure (mmHg)'    219
# Name: PARAM, dtype: int64

# %%
sum = gg["AVAL"].agg({"count","mean","std","sem","median","min","max"})

# %%
list(sum)
# Out:
# ['std', 'mean', 'sem', 'median', 'count', 'max', 'min']

# %%
sum.reset_index(inplace=True)
sum.sort_values(by=["AVISITN","AVISIT","TRTPN","TRTP"])
# Out:
#            TRTPN                     TRTP       AVISITN               AVISIT  \
# 0   5.397605e-79               b'Placebo'  5.397605e-79          b'Baseline'
# 11  5.400000e+01   b'Xanomeline Low Dose'  5.397605e-79          b'Baseline'
# 22  8.100000e+01  b'Xanomeline High Dose'  5.397605e-79          b'Baseline'
# 1   5.397605e-79               b'Placebo'  2.000000e+00            b'Week 2'
# 12  5.400000e+01   b'Xanomeline Low Dose'  2.000000e+00            b'Week 2'
# 23  8.100000e+01  b'Xanomeline High Dose'  2.000000e+00            b'Week 2'
# 2   5.397605e-79               b'Placebo'  4.000000e+00            b'Week 4'
# 13  5.400000e+01   b'Xanomeline Low Dose'  4.000000e+00            b'Week 4'
# 24  8.100000e+01  b'Xanomeline High Dose'  4.000000e+00            b'Week 4'
# 3   5.397605e-79               b'Placebo'  6.000000e+00            b'Week 6'
# 14  5.400000e+01   b'Xanomeline Low Dose'  6.000000e+00            b'Week 6'
# 25  8.100000e+01  b'Xanomeline High Dose'  6.000000e+00            b'Week 6'
# 4   5.397605e-79               b'Placebo'  8.000000e+00            b'Week 8'
# 15  5.400000e+01   b'Xanomeline Low Dose'  8.000000e+00            b'Week 8'
# 26  8.100000e+01  b'Xanomeline High Dose'  8.000000e+00            b'Week 8'
# 5   5.397605e-79               b'Placebo'  1.200000e+01           b'Week 12'
# 16  5.400000e+01   b'Xanomeline Low Dose'  1.200000e+01           b'Week 12'
# 27  8.100000e+01  b'Xanomeline High Dose'  1.200000e+01           b'Week 12'
# 6   5.397605e-79               b'Placebo'  1.600000e+01           b'Week 16'
# 17  5.400000e+01   b'Xanomeline Low Dose'  1.600000e+01           b'Week 16'
# 28  8.100000e+01  b'Xanomeline High Dose'  1.600000e+01           b'Week 16'
# 7   5.397605e-79               b'Placebo'  2.000000e+01           b'Week 20'
# 18  5.400000e+01   b'Xanomeline Low Dose'  2.000000e+01           b'Week 20'
# 29  8.100000e+01  b'Xanomeline High Dose'  2.000000e+01           b'Week 20'
# 8   5.397605e-79               b'Placebo'  2.400000e+01           b'Week 24'
# 19  5.400000e+01   b'Xanomeline Low Dose'  2.400000e+01           b'Week 24'
# 30  8.100000e+01  b'Xanomeline High Dose'  2.400000e+01           b'Week 24'
# 9   5.397605e-79               b'Placebo'  2.600000e+01           b'Week 26'
# 20  5.400000e+01   b'Xanomeline Low Dose'  2.600000e+01           b'Week 26'
# 31  8.100000e+01  b'Xanomeline High Dose'  2.600000e+01           b'Week 26'
# 10  5.397605e-79               b'Placebo'  9.900000e+01  b'End of Treatment'
# 21  5.400000e+01   b'Xanomeline Low Dose'  9.900000e+01  b'End of Treatment'
# 32  8.100000e+01  b'Xanomeline High Dose'  9.900000e+01  b'End of Treatment'
#
#           std       mean       sem  median  count    max   min
# 0   10.909748  77.094118  0.683195    78.0    255  110.0  40.0
# 11  10.251005  76.357143  0.645753    76.0    252  108.0  48.0
# 22  10.270289  78.265873  0.646967    79.5    252  108.0  51.0
# 1   10.423793  74.456349  0.656637    74.0    252  100.0  45.0
# 12   9.890389  76.219124  0.624276    76.0    251  102.0  45.0
# 23  10.777519  76.427984  0.691378    77.0    243  118.0  43.0
# 2   11.458946  75.430894  0.730596    76.0    246  100.0  39.0
# 13   9.348796  76.004630  0.636105    78.0    216  102.0  50.0
# 24   9.579977  76.799087  0.647355    78.0    219  100.0  54.0
# 3   10.204286  74.482456  0.675795    74.0    228  110.0  48.0
# 14   9.178400  74.902564  0.657279    76.0    195  100.0  50.0
# 25   9.899665  75.256158  0.694820    76.0    203   98.0  52.0
# 4    9.288615  75.246575  0.627666    76.0    219  101.0  49.0
# 15  10.750913  75.400000  0.801326    74.5    180  100.0  52.0
# 26   9.284305  77.369048  0.716300    78.0    168   98.0  54.0
# 5   10.919522  74.289855  0.758959    73.0    207  104.0  49.0
# 16  10.836118  75.673077  0.867584    75.0    156  100.0  50.0
# 27   9.212551  74.606667  0.752202    76.0    150   92.0  54.0
# 6   11.103449  75.117647  0.777397    76.5    204   98.0  49.0
# 17  10.128110  75.230159  0.902284    75.5    126   98.0  55.0
# 28   9.116877  76.027027  0.865336    78.0    111   92.0  50.0
# 7   10.577603  73.398990  0.751718    72.0    198  100.0  48.0
# 18   9.735837  73.666667  1.026247    72.0     90   98.0  51.0
# 29  10.355009  74.072917  1.056854    72.0     96   98.0  54.0
# 8   11.833763  73.796610  0.889480    74.0    177  117.0  44.0
# 19   9.759247  76.209877  1.084361    76.0     81   98.0  57.0
# 30  10.236309  74.933333  1.079002    75.5     90   98.0  50.0
# 9   10.945070  72.632184  0.829744    72.0    174   98.0  39.0
# 20   9.891155  72.946667  1.142132    72.0     75   92.0  56.0
# 31  10.520668  74.547619  1.147899    74.0     84   93.0  50.0
# 10  11.044844  74.056911  0.704194    74.0    246  100.0  39.0
# 21   9.125981  73.819444  0.620944    72.0    216  102.0  51.0
# 32  10.381399  75.141553  0.701510    76.0    219   99.0  50.0

# %%
sum_t=pd.melt(sum,id_vars=["AVISITN","AVISIT","TRTPN","TRTP"],var_name='stats', value_name='valn')

# %%
sum_t.head()
# Out:
#         AVISITN       AVISIT         TRTPN        TRTP stats       valn
# 0  5.397605e-79  b'Baseline'  5.397605e-79  b'Placebo'   std  10.909748
# 1  2.000000e+00    b'Week 2'  5.397605e-79  b'Placebo'   std  10.423793
# 2  4.000000e+00    b'Week 4'  5.397605e-79  b'Placebo'   std  11.458946
# 3  6.000000e+00    b'Week 6'  5.397605e-79  b'Placebo'   std  10.204286
# 4  8.000000e+00    b'Week 8'  5.397605e-79  b'Placebo'   std   9.288615

# %%
sum_t.dtypes
# Out:
# AVISITN    float64
# AVISIT      object
# TRTPN      float64
# TRTP        object
# stats       object
# valn       float64
# dtype: object

# %%
# refer to http://pbpython.com/pandas_dtypes.html
sum_t["AVISITN"] = sum_t["AVISITN"].astype("int")
sum_t["TRTPN"] = sum_t["TRTPN"].astype("int")

# %%
sum_t.dtypes
# Out:
# AVISITN      int64
# AVISIT      object
# TRTPN        int64
# TRTP        object
# stats       object
# valn       float64
# dtype: object

# %%
sum_t.head()
# Out:
#    AVISITN       AVISIT  TRTPN        TRTP stats       valn
# 0        0  b'Baseline'      0  b'Placebo'   std  10.909748
# 1        2    b'Week 2'      0  b'Placebo'   std  10.423793
# 2        4    b'Week 4'      0  b'Placebo'   std  11.458946
# 3        6    b'Week 6'      0  b'Placebo'   std  10.204286
# 4        8    b'Week 8'      0  b'Placebo'   std   9.288615

# %%
sum_t.loc[sum_t["stats"] == "count", "statn"] = 1
sum_t.loc[sum_t["stats"] == "mean", "statn"] = 2
sum_t.loc[sum_t["stats"] == "median", "statn"] = 3
sum_t.loc[sum_t["stats"] == "std", "statn"] = 4
sum_t.loc[sum_t["stats"] == "sem", "statn"] = 5
sum_t.loc[sum_t["stats"] == "min", "statn"] = 6
sum_t.loc[sum_t["stats"] == "max", "statn"] = 7

# %%
sum_t.loc[sum_t["stats"] == "count", "statlabel"] = "n"
sum_t.loc[sum_t["stats"] == "mean", "statlabel"] = "Mean"
sum_t.loc[sum_t["stats"] == "median", "statlabel"] = "Median"
sum_t.loc[sum_t["stats"] == "std", "statlabel"] = "S.D."
sum_t.loc[sum_t["stats"] == "sem", "statlabel"] = "S.E."
sum_t.loc[sum_t["stats"] == "min", "statlabel"] = "Min"
sum_t.loc[sum_t["stats"] == "max", "statlabel"] = "Max"

# %%
sum_t.head()
# Out:
#    AVISITN       AVISIT  TRTPN        TRTP stats       valn  statn statlabel  \
# 0        0  b'Baseline'      0  b'Placebo'   std  10.909748    4.0      S.D.
# 1        2    b'Week 2'      0  b'Placebo'   std  10.423793    4.0      S.D.
# 2        4    b'Week 4'      0  b'Placebo'   std  11.458946    4.0      S.D.
# 3        6    b'Week 6'      0  b'Placebo'   std  10.204286    4.0      S.D.
# 4        8    b'Week 8'      0  b'Placebo'   std   9.288615    4.0      S.D.
#
#    varn   var                            varlabel
# 0     1  AVAL  b'Diastolic Blood Pressure (mmHg)'
# 1     1  AVAL  b'Diastolic Blood Pressure (mmHg)'
# 2     1  AVAL  b'Diastolic Blood Pressure (mmHg)'
# 3     1  AVAL  b'Diastolic Blood Pressure (mmHg)'
# 4     1  AVAL  b'Diastolic Blood Pressure (mmHg)'

# %%
sum_t["varn"] = 1
sum_t["var"] = "AVAL"
sum_t["varlabel"] = b'Diastolic Blood Pressure (mmHg)'
sum_t.head()
# Out:
#    AVISITN       AVISIT  TRTPN        TRTP stats       valn  statn statlabel  \
# 0        0  b'Baseline'      0  b'Placebo'   std  10.909748    4.0      S.D.
# 1        2    b'Week 2'      0  b'Placebo'   std  10.423793    4.0      S.D.
# 2        4    b'Week 4'      0  b'Placebo'   std  11.458946    4.0      S.D.
# 3        6    b'Week 6'      0  b'Placebo'   std  10.204286    4.0      S.D.
# 4        8    b'Week 8'      0  b'Placebo'   std   9.288615    4.0      S.D.
#
#    varn   var                            varlabel
# 0     1  AVAL  b'Diastolic Blood Pressure (mmHg)'
# 1     1  AVAL  b'Diastolic Blood Pressure (mmHg)'
# 2     1  AVAL  b'Diastolic Blood Pressure (mmHg)'
# 3     1  AVAL  b'Diastolic Blood Pressure (mmHg)'
# 4     1  AVAL  b'Diastolic Blood Pressure (mmHg)'

# %%
final=sum_t.pivot_table(index=["AVISITN","AVISIT","varn","var","varlabel","statn","stats","statlabel"], columns=["TRTPN","TRTP"], values='valn').reset_index()
final.head()
# Out:
# TRTPN AVISITN       AVISIT varn   var                            varlabel  \
# TRTP
# 0           0  b'Baseline'    1  AVAL  b'Diastolic Blood Pressure (mmHg)'
# 1           0  b'Baseline'    1  AVAL  b'Diastolic Blood Pressure (mmHg)'
# 2           0  b'Baseline'    1  AVAL  b'Diastolic Blood Pressure (mmHg)'
# 3           0  b'Baseline'    1  AVAL  b'Diastolic Blood Pressure (mmHg)'
# 4           0  b'Baseline'    1  AVAL  b'Diastolic Blood Pressure (mmHg)'
#
# TRTPN statn   stats statlabel           0                     54  \
# TRTP                           b'Placebo' b'Xanomeline Low Dose'
# 0       1.0   count         n  255.000000             252.000000
# 1       2.0    mean      Mean   77.094118              76.357143
# 2       3.0  median    Median   78.000000              76.000000
# 3       4.0     std      S.D.   10.909748              10.251005
# 4       5.0     sem      S.E.    0.683195               0.645753
#
# TRTPN                      81
# TRTP  b'Xanomeline High Dose'
# 0                  252.000000
# 1                   78.265873
# 2                   79.500000
# 3                   10.270289
# 4                    0.646967

# %%
list(final)
# Out:
# [('AVISITN', ''),
#  ('AVISIT', ''),
#  ('varn', ''),
#  ('var', ''),
#  ('varlabel', ''),
#  ('statn', ''),
#  ('stats', ''),
#  ('statlabel', ''),
#  (0, b'Placebo'),
#  (54, b'Xanomeline Low Dose'),
#  (81, b'Xanomeline High Dose')]
